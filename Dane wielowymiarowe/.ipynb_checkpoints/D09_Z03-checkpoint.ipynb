# %% [markdown]
# # Wielowymiarowy rozkład normalny

# %%
import matplotlib.pylab as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.mlab as mlab
from matplotlib import cm
from scipy.stats import multivariate_normal

# %% [markdown]
# # Narysujmy gęstość dwuwymiarowego rozkładu Normalnego

# %%
X = np.arange(-3, 3, 0.01)
Y = np.arange(-3, 3, 0.01)
X, Y = np.meshgrid(X, Y)
cov = np.array([[ 0.6744121 , -0.16938146], [,  0.21243464]]) #-0.16938146

rv = multivariate_normal([0, 0], cov)
Z = rv.pdf(np.dstack((X, Y)))
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1, 2, 1, projection='3d')
_ = ax.plot_surface(X, Y, Z, linewidth=0.2, cmap=cm.viridis)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-3836dff82a39> in <module>
#       4 cov = np.array([[ 0.6744121 , 1.16938146], [1.16938146,  0.21243464]])
#       5
# ----> 6 rv = multivariate_normal([0, 0], cov)
#       7 Z = rv.pdf(np.dstack((X, Y)))
#       8 fig = plt.figure(figsize=(20,10))
#
# D:\Programy\anaconda3\lib\site-packages\scipy\stats\_multivariate.py in __call__(self, mean, cov, allow_singular, seed)
#     361         return multivariate_normal_frozen(mean, cov,
#     362                                           allow_singular=allow_singular,
# --> 363                                           seed=seed)
#     364
#     365     def _process_parameters(self, dim, mean, cov):
#
# D:\Programy\anaconda3\lib\site-packages\scipy\stats\_multivariate.py in __init__(self, mean, cov, allow_singular, seed, maxpts, abseps, releps)
#     734         self.dim, self.mean, self.cov = self._dist._process_parameters(
#     735                                                             None, mean, cov)
# --> 736         self.cov_info = _PSD(self.cov, allow_singular=allow_singular)
#     737         if not maxpts:
#     738             maxpts = 1000000 * self.dim
#
# D:\Programy\anaconda3\lib\site-packages\scipy\stats\_multivariate.py in __init__(self, M, cond, rcond, lower, check_finite, allow_singular)
#     158         eps = _eigvalsh_to_eps(s, cond, rcond)
#     159         if np.min(s) < -eps:
# --> 160             raise ValueError('the input matrix must be positive semidefinite')
#     161         d = s[s > eps]
#     162         if len(d) < len(s) and not allow_singular:
#
# ValueError: the input matrix must be positive semidefinite

# %% [markdown]
# # Narysujmy kontury gęstości dwuwymiarowego rozkładu Normalnego

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.set_ylim(-1.5, 1.5)
ax.set_xlim(-2, 2)
levels = np.arange(0.0, 0.5, 0.01)
_ = plt.contour(X, Y, Z, levels, origincmap=cm.viridis)
plt.show()
# Out:
# D:\Programy\anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: The following kwargs were not used by contour: 'origincmap'
#   """

# %% [markdown]
# # Wylosujmy próbkę z dwuwymiarowego rozkładu Normalnego

# %%
mean = [0, 0]
cov = np.array([[ 0.6744121 , -0.16938146], [-0.16938146,  0.21243464]])
samples = np.random.multivariate_normal(mean, cov, 1000)
w, v = np.linalg.eig(cov)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
_ = plt.scatter(samples[:,0], samples[:,1])
plt.show()

# %%
samples
# Out:
# array([[ 0.42629356, -0.26798439],
#        [-0.69041463,  0.38684617],
#        [-0.70469521,  0.06707238],
#        ...,
#        [ 0.41045119,  0.21475553],
#        [-0.00891633, -0.65161202],
#        [-1.12409905,  0.52857111]])
